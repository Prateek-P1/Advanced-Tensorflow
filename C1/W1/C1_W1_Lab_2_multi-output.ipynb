# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 990us/sample - loss: 277.2295 - y1_output_loss: 130.1887 - y2_output_loss: 144.9843 - y1_output_root_mean_squared_error: 11.4615 - y2_output_root_mean_squared_error: 12.0774 - val_loss: 31.2202 - val_y1_output_loss: 15.4514 - val_y2_output_loss: 14.9502 - val_y1_output_root_mean_squared_error: 3.9894 - val_y2_output_root_mean_squared_error: 3.9121
# Epoch 2/500
# 614/614 [==============================] - 0s 151us/sample - loss: 32.3628 - y1_output_loss: 12.8678 - y2_output_loss: 19.2292 - y1_output_root_mean_squared_error: 3.6011 - y2_output_root_mean_squared_error: 4.4040 - val_loss: 20.4273 - val_y1_output_loss: 9.5831 - val_y2_output_loss: 10.6397 - val_y1_output_root_mean_squared_error: 3.1088 - val_y2_output_root_mean_squared_error: 3.2806
# Epoch 3/500
# 614/614 [==============================] - 0s 146us/sample - loss: 27.1123 - y1_output_loss: 10.1390 - y2_output_loss: 17.1585 - y1_output_root_mean_squared_error: 3.1818 - y2_output_root_mean_squared_error: 4.1217 - val_loss: 36.9484 - val_y1_output_loss: 13.2290 - val_y2_output_loss: 24.1070 - val_y1_output_root_mean_squared_error: 3.6092 - val_y2_output_root_mean_squared_error: 4.8910
# Epoch 4/500
# 614/614 [==============================] - 0s 149us/sample - loss: 24.9652 - y1_output_loss: 9.9405 - y2_output_loss: 15.0561 - y1_output_root_mean_squared_error: 3.1363 - y2_output_root_mean_squared_error: 3.8896 - val_loss: 21.3020 - val_y1_output_loss: 9.2225 - val_y2_output_loss: 12.2122 - val_y1_output_root_mean_squared_error: 3.0239 - val_y2_output_root_mean_squared_error: 3.4869
# Epoch 5/500
# 614/614 [==============================] - 0s 148us/sample - loss: 24.0109 - y1_output_loss: 9.0549 - y2_output_loss: 14.7442 - y1_output_root_mean_squared_error: 3.0223 - y2_output_root_mean_squared_error: 3.8570 - val_loss: 25.7601 - val_y1_output_loss: 8.6810 - val_y2_output_loss: 16.7519 - val_y1_output_root_mean_squared_error: 2.9416 - val_y2_output_root_mean_squared_error: 4.1361
# Epoch 6/500
# 614/614 [==============================] - 0s 145us/sample - loss: 27.2769 - y1_output_loss: 9.7398 - y2_output_loss: 17.3685 - y1_output_root_mean_squared_error: 3.1233 - y2_output_root_mean_squared_error: 4.1859 - val_loss: 30.1931 - val_y1_output_loss: 12.9314 - val_y2_output_loss: 17.2237 - val_y1_output_root_mean_squared_error: 3.5931 - val_y2_output_root_mean_squared_error: 4.1572
# Epoch 7/500
# 614/614 [==============================] - 0s 148us/sample - loss: 25.4399 - y1_output_loss: 9.6597 - y2_output_loss: 16.1516 - y1_output_root_mean_squared_error: 3.0684 - y2_output_root_mean_squared_error: 4.0031 - val_loss: 26.3947 - val_y1_output_loss: 11.2634 - val_y2_output_loss: 16.3132 - val_y1_output_root_mean_squared_error: 3.2620 - val_y2_output_root_mean_squared_error: 3.9691
# Epoch 8/500
# 614/614 [==============================] - 0s 144us/sample - loss: 22.8833 - y1_output_loss: 8.8130 - y2_output_loss: 14.1112 - y1_output_root_mean_squared_error: 2.9574 - y2_output_root_mean_squared_error: 3.7599 - val_loss: 28.6804 - val_y1_output_loss: 11.2675 - val_y2_output_loss: 17.9520 - val_y1_output_root_mean_squared_error: 3.3132 - val_y2_output_root_mean_squared_error: 4.2075
# Epoch 9/500
# 614/614 [==============================] - 0s 141us/sample - loss: 23.7820 - y1_output_loss: 8.7466 - y2_output_loss: 14.8617 - y1_output_root_mean_squared_error: 2.9662 - y2_output_root_mean_squared_error: 3.8709 - val_loss: 17.5835 - val_y1_output_loss: 8.7689 - val_y2_output_loss: 9.1459 - val_y1_output_root_mean_squared_error: 2.9291 - val_y2_output_root_mean_squared_error: 3.0006
# Epoch 10/500
# 614/614 [==============================] - 0s 141us/sample - loss: 20.7956 - y1_output_loss: 8.2824 - y2_output_loss: 12.8386 - y1_output_root_mean_squared_error: 2.8643 - y2_output_root_mean_squared_error: 3.5484 - val_loss: 42.4728 - val_y1_output_loss: 11.4539 - val_y2_output_loss: 31.4385 - val_y1_output_root_mean_squared_error: 3.3485 - val_y2_output_root_mean_squared_error: 5.5911
# Epoch 11/500
# 614/614 [==============================] - 0s 156us/sample - loss: 20.7351 - y1_output_loss: 7.8979 - y2_output_loss: 13.4606 - y1_output_root_mean_squared_error: 2.8004 - y2_output_root_mean_squared_error: 3.5906 - val_loss: 52.3082 - val_y1_output_loss: 12.9335 - val_y2_output_loss: 39.2297 - val_y1_output_root_mean_squared_error: 3.5868 - val_y2_output_root_mean_squared_error: 6.2804
# Epoch 12/500
# 614/614 [==============================] - 0s 145us/sample - loss: 27.2225 - y1_output_loss: 9.3778 - y2_output_loss: 17.9304 - y1_output_root_mean_squared_error: 3.0672 - y2_output_root_mean_squared_error: 4.2207 - val_loss: 44.0007 - val_y1_output_loss: 11.5478 - val_y2_output_loss: 32.9098 - val_y1_output_root_mean_squared_error: 3.3603 - val_y2_output_root_mean_squared_error: 5.7192
# Epoch 13/500
# 614/614 [==============================] - 0s 144us/sample - loss: 18.1135 - y1_output_loss: 6.7372 - y2_output_loss: 11.6061 - y1_output_root_mean_squared_error: 2.5824 - y2_output_root_mean_squared_error: 3.3830 - val_loss: 22.9438 - val_y1_output_loss: 8.0540 - val_y2_output_loss: 14.4130 - val_y1_output_root_mean_squared_error: 2.8628 - val_y2_output_root_mean_squared_error: 3.8404
# Epoch 14/500
# 614/614 [==============================] - 0s 143us/sample - loss: 17.7651 - y1_output_loss: 7.0459 - y2_output_loss: 10.6992 - y1_output_root_mean_squared_error: 2.6613 - y2_output_root_mean_squared_error: 3.2685 - val_loss: 24.3605 - val_y1_output_loss: 9.9020 - val_y2_output_loss: 15.3934 - val_y1_output_root_mean_squared_error: 3.0713 - val_y2_output_root_mean_squared_error: 3.8636
# Epoch 15/500
# 614/614 [==============================] - 0s 143us/sample - loss: 20.4090 - y1_output_loss: 7.3486 - y2_output_loss: 13.7086 - y1_output_root_mean_squared_error: 2.6757 - y2_output_root_mean_squared_error: 3.6400 - val_loss: 54.4454 - val_y1_output_loss: 12.2765 - val_y2_output_loss: 40.8970 - val_y1_output_root_mean_squared_error: 3.5609 - val_y2_output_root_mean_squared_error: 6.4626
# Epoch 16/500
# 614/614 [==============================] - 0s 144us/sample - loss: 18.6116 - y1_output_loss: 6.6845 - y2_output_loss: 11.8415 - y1_output_root_mean_squared_error: 2.5947 - y2_output_root_mean_squared_error: 3.4466 - val_loss: 15.5657 - val_y1_output_loss: 7.0343 - val_y2_output_loss: 8.3375 - val_y1_output_root_mean_squared_error: 2.6553 - val_y2_output_root_mean_squared_error: 2.9181
# Epoch 17/500
# 614/614 [==============================] - 0s 157us/sample - loss: 19.2121 - y1_output_loss: 6.6642 - y2_output_loss: 12.4760 - y1_output_root_mean_squared_error: 2.5905 - y2_output_root_mean_squared_error: 3.5357 - val_loss: 24.1268 - val_y1_output_loss: 8.2711 - val_y2_output_loss: 16.4910 - val_y1_output_root_mean_squared_error: 2.8210 - val_y2_output_root_mean_squared_error: 4.0210
# Epoch 18/500
# 614/614 [==============================] - 0s 146us/sample - loss: 18.3748 - y1_output_loss: 6.4468 - y2_output_loss: 11.7844 - y1_output_root_mean_squared_error: 2.5485 - y2_output_root_mean_squared_error: 3.4468 - val_loss: 15.8743 - val_y1_output_loss: 6.3524 - val_y2_output_loss: 9.8572 - val_y1_output_root_mean_squared_error: 2.4907 - val_y2_output_root_mean_squared_error: 3.1098
# Epoch 19/500
# 614/614 [==============================] - 0s 142us/sample - loss: 13.9715 - y1_output_loss: 5.2782 - y2_output_loss: 8.6526 - y1_output_root_mean_squared_error: 2.3005 - y2_output_root_mean_squared_error: 2.9461 - val_loss: 19.5766 - val_y1_output_loss: 7.4004 - val_y2_output_loss: 11.6783 - val_y1_output_root_mean_squared_error: 2.7460 - val_y2_output_root_mean_squared_error: 3.4693
# Epoch 20/500
# 614/614 [==============================] - 0s 142us/sample - loss: 14.3132 - y1_output_loss: 5.3582 - y2_output_loss: 8.8527 - y1_output_root_mean_squared_error: 2.3241 - y2_output_root_mean_squared_error: 2.9853 - val_loss: 11.2411 - val_y1_output_loss: 5.5036 - val_y2_output_loss: 5.5557 - val_y1_output_root_mean_squared_error: 2.3582 - val_y2_output_root_mean_squared_error: 2.3833
# Epoch 21/500
# 614/614 [==============================] - 0s 140us/sample - loss: 12.1895 - y1_output_loss: 4.7940 - y2_output_loss: 7.5022 - y1_output_root_mean_squared_error: 2.1730 - y2_output_root_mean_squared_error: 2.7327 - val_loss: 11.4626 - val_y1_output_loss: 5.6355 - val_y2_output_loss: 5.9802 - val_y1_output_root_mean_squared_error: 2.3622 - val_y2_output_root_mean_squared_error: 2.4254
# Epoch 22/500
# 614/614 [==============================] - 0s 148us/sample - loss: 15.2368 - y1_output_loss: 5.3241 - y2_output_loss: 9.8141 - y1_output_root_mean_squared_error: 2.3121 - y2_output_root_mean_squared_error: 3.1450 - val_loss: 10.5163 - val_y1_output_loss: 5.1512 - val_y2_output_loss: 5.3040 - val_y1_output_root_mean_squared_error: 2.2696 - val_y2_output_root_mean_squared_error: 2.3163
# Epoch 23/500
# 614/614 [==============================] - 0s 154us/sample - loss: 12.9348 - y1_output_loss: 4.5858 - y2_output_loss: 8.2802 - y1_output_root_mean_squared_error: 2.1500 - y2_output_root_mean_squared_error: 2.8831 - val_loss: 10.8708 - val_y1_output_loss: 5.1405 - val_y2_output_loss: 5.6364 - val_y1_output_root_mean_squared_error: 2.2754 - val_y2_output_root_mean_squared_error: 2.3860
# Epoch 24/500
# 614/614 [==============================] - 0s 149us/sample - loss: 12.4673 - y1_output_loss: 4.3550 - y2_output_loss: 8.0105 - y1_output_root_mean_squared_error: 2.0961 - y2_output_root_mean_squared_error: 2.8414 - val_loss: 15.0518 - val_y1_output_loss: 5.1859 - val_y2_output_loss: 10.0622 - val_y1_output_root_mean_squared_error: 2.2570 - val_y2_output_root_mean_squared_error: 3.1556
# Epoch 25/500
# 614/614 [==============================] - 0s 148us/sample - loss: 11.0435 - y1_output_loss: 4.3678 - y2_output_loss: 6.8424 - y1_output_root_mean_squared_error: 2.0499 - y2_output_root_mean_squared_error: 2.6156 - val_loss: 15.1924 - val_y1_output_loss: 6.8633 - val_y2_output_loss: 7.8272 - val_y1_output_root_mean_squared_error: 2.6638 - val_y2_output_root_mean_squared_error: 2.8454
# Epoch 26/500
# 614/614 [==============================] - 0s 142us/sample - loss: 12.4958 - y1_output_loss: 4.4685 - y2_output_loss: 8.0005 - y1_output_root_mean_squared_error: 2.1179 - y2_output_root_mean_squared_error: 2.8303 - val_loss: 16.9066 - val_y1_output_loss: 5.4462 - val_y2_output_loss: 11.6871 - val_y1_output_root_mean_squared_error: 2.3088 - val_y2_output_root_mean_squared_error: 3.4024
# Epoch 27/500
# 614/614 [==============================] - 0s 136us/sample - loss: 10.8194 - y1_output_loss: 3.8585 - y2_output_loss: 6.8740 - y1_output_root_mean_squared_error: 1.9730 - y2_output_root_mean_squared_error: 2.6319 - val_loss: 10.8833 - val_y1_output_loss: 4.6187 - val_y2_output_loss: 6.4006 - val_y1_output_root_mean_squared_error: 2.1281 - val_y2_output_root_mean_squared_error: 2.5208
# Epoch 28/500
# 614/614 [==============================] - 0s 150us/sample - loss: 10.6292 - y1_output_loss: 3.7450 - y2_output_loss: 6.8031 - y1_output_root_mean_squared_error: 1.9423 - y2_output_root_mean_squared_error: 2.6186 - val_loss: 10.1140 - val_y1_output_loss: 4.3360 - val_y2_output_loss: 5.5112 - val_y1_output_root_mean_squared_error: 2.1073 - val_y2_output_root_mean_squared_error: 2.3819
# Epoch 29/500
# 614/614 [==============================] - 0s 157us/sample - loss: 13.8112 - y1_output_loss: 4.2726 - y2_output_loss: 9.4483 - y1_output_root_mean_squared_error: 2.0715 - y2_output_root_mean_squared_error: 3.0855 - val_loss: 20.6797 - val_y1_output_loss: 6.8335 - val_y2_output_loss: 13.1688 - val_y1_output_root_mean_squared_error: 2.6580 - val_y2_output_root_mean_squared_error: 3.6898
# Epoch 30/500
# 614/614 [==============================] - 0s 152us/sample - loss: 11.0321 - y1_output_loss: 3.4387 - y2_output_loss: 7.5128 - y1_output_root_mean_squared_error: 1.8619 - y2_output_root_mean_squared_error: 2.7505 - val_loss: 23.9205 - val_y1_output_loss: 7.8333 - val_y2_output_loss: 15.2807 - val_y1_output_root_mean_squared_error: 2.8493 - val_y2_output_root_mean_squared_error: 3.9752
# Epoch 31/500
# 614/614 [==============================] - 0s 152us/sample - loss: 11.3326 - y1_output_loss: 3.6150 - y2_output_loss: 7.9506 - y1_output_root_mean_squared_error: 1.8766 - y2_output_root_mean_squared_error: 2.7948 - val_loss: 15.8349 - val_y1_output_loss: 6.0805 - val_y2_output_loss: 9.2306 - val_y1_output_root_mean_squared_error: 2.5129 - val_y2_output_root_mean_squared_error: 3.0855
# Epoch 32/500
# 614/614 [==============================] - 0s 143us/sample - loss: 10.9292 - y1_output_loss: 3.6171 - y2_output_loss: 7.3540 - y1_output_root_mean_squared_error: 1.8856 - y2_output_root_mean_squared_error: 2.7155 - val_loss: 14.4597 - val_y1_output_loss: 5.0847 - val_y2_output_loss: 8.9215 - val_y1_output_root_mean_squared_error: 2.2881 - val_y2_output_root_mean_squared_error: 3.0371
# Epoch 33/500
# 614/614 [==============================] - 0s 144us/sample - loss: 8.4174 - y1_output_loss: 2.8755 - y2_output_loss: 5.4792 - y1_output_root_mean_squared_error: 1.7019 - y2_output_root_mean_squared_error: 2.3496 - val_loss: 8.7717 - val_y1_output_loss: 3.9705 - val_y2_output_loss: 4.6873 - val_y1_output_root_mean_squared_error: 1.9980 - val_y2_output_root_mean_squared_error: 2.1863
# Epoch 34/500
# 614/614 [==============================] - 0s 142us/sample - loss: 8.7627 - y1_output_loss: 2.8248 - y2_output_loss: 6.0145 - y1_output_root_mean_squared_error: 1.6777 - y2_output_root_mean_squared_error: 2.4389 - val_loss: 8.7538 - val_y1_output_loss: 3.7163 - val_y2_output_loss: 4.9311 - val_y1_output_root_mean_squared_error: 1.9317 - val_y2_output_root_mean_squared_error: 2.2410
# Epoch 35/500
# 614/614 [==============================] - 0s 154us/sample - loss: 10.3915 - y1_output_loss: 3.2457 - y2_output_loss: 7.1000 - y1_output_root_mean_squared_error: 1.8062 - y2_output_root_mean_squared_error: 2.6700 - val_loss: 18.6478 - val_y1_output_loss: 4.9996 - val_y2_output_loss: 13.5375 - val_y1_output_root_mean_squared_error: 2.2328 - val_y2_output_root_mean_squared_error: 3.6962
# Epoch 36/500
# 614/614 [==============================] - 0s 147us/sample - loss: 9.3740 - y1_output_loss: 2.8911 - y2_output_loss: 6.4998 - y1_output_root_mean_squared_error: 1.7014 - y2_output_root_mean_squared_error: 2.5455 - val_loss: 14.9000 - val_y1_output_loss: 4.4750 - val_y2_output_loss: 9.9684 - val_y1_output_root_mean_squared_error: 2.1496 - val_y2_output_root_mean_squared_error: 3.2061
# Epoch 37/500
# 614/614 [==============================] - 0s 147us/sample - loss: 8.6383 - y1_output_loss: 2.9553 - y2_output_loss: 5.6359 - y1_output_root_mean_squared_error: 1.7216 - y2_output_root_mean_squared_error: 2.3821 - val_loss: 9.2747 - val_y1_output_loss: 3.6657 - val_y2_output_loss: 5.3607 - val_y1_output_root_mean_squared_error: 1.9388 - val_y2_output_root_mean_squared_error: 2.3486
# Epoch 38/500
# 614/614 [==============================] - 0s 134us/sample - loss: 10.5564 - y1_output_loss: 3.3356 - y2_output_loss: 7.2232 - y1_output_root_mean_squared_error: 1.8274 - y2_output_root_mean_squared_error: 2.6865 - val_loss: 7.1674 - val_y1_output_loss: 3.1797 - val_y2_output_loss: 3.8220 - val_y1_output_root_mean_squared_error: 1.7946 - val_y2_output_root_mean_squared_error: 1.9867
# Epoch 39/500
# 614/614 [==============================] - 0s 142us/sample - loss: 7.2430 - y1_output_loss: 2.3662 - y2_output_loss: 4.8330 - y1_output_root_mean_squared_error: 1.5386 - y2_output_root_mean_squared_error: 2.2081 - val_loss: 8.8264 - val_y1_output_loss: 3.9535 - val_y2_output_loss: 4.6177 - val_y1_output_root_mean_squared_error: 2.0158 - val_y2_output_root_mean_squared_error: 2.1824
# Epoch 40/500
# 614/614 [==============================] - 0s 141us/sample - loss: 8.9040 - y1_output_loss: 2.7075 - y2_output_loss: 6.2164 - y1_output_root_mean_squared_error: 1.6351 - y2_output_root_mean_squared_error: 2.4961 - val_loss: 11.3672 - val_y1_output_loss: 3.7568 - val_y2_output_loss: 7.2520 - val_y1_output_root_mean_squared_error: 1.9670 - val_y2_output_root_mean_squared_error: 2.7383
# Epoch 41/500
# 614/614 [==============================] - 0s 154us/sample - loss: 7.8474 - y1_output_loss: 2.5364 - y2_output_loss: 5.3577 - y1_output_root_mean_squared_error: 1.5882 - y2_output_root_mean_squared_error: 2.3076 - val_loss: 6.4117 - val_y1_output_loss: 2.9935 - val_y2_output_loss: 3.2065 - val_y1_output_root_mean_squared_error: 1.7584 - val_y2_output_root_mean_squared_error: 1.8220
# Epoch 42/500
# 614/614 [==============================] - 0s 146us/sample - loss: 8.9062 - y1_output_loss: 2.8515 - y2_output_loss: 5.9774 - y1_output_root_mean_squared_error: 1.6957 - y2_output_root_mean_squared_error: 2.4558 - val_loss: 6.9720 - val_y1_output_loss: 2.7632 - val_y2_output_loss: 4.1027 - val_y1_output_root_mean_squared_error: 1.6672 - val_y2_output_root_mean_squared_error: 2.0476
# Epoch 43/500
# 614/614 [==============================] - 0s 142us/sample - loss: 6.4776 - y1_output_loss: 2.1644 - y2_output_loss: 4.3121 - y1_output_root_mean_squared_error: 1.4684 - y2_output_root_mean_squared_error: 2.0788 - val_loss: 7.6614 - val_y1_output_loss: 2.4561 - val_y2_output_loss: 4.9809 - val_y1_output_root_mean_squared_error: 1.5931 - val_y2_output_root_mean_squared_error: 2.2635
# Epoch 44/500
# 614/614 [==============================] - 0s 144us/sample - loss: 6.6789 - y1_output_loss: 2.1440 - y2_output_loss: 4.5326 - y1_output_root_mean_squared_error: 1.4689 - y2_output_root_mean_squared_error: 2.1263 - val_loss: 18.6179 - val_y1_output_loss: 3.8780 - val_y2_output_loss: 14.6130 - val_y1_output_root_mean_squared_error: 1.9655 - val_y2_output_root_mean_squared_error: 3.8412
# Epoch 45/500
# 614/614 [==============================] - 0s 144us/sample - loss: 8.3105 - y1_output_loss: 2.4874 - y2_output_loss: 5.7520 - y1_output_root_mean_squared_error: 1.5843 - y2_output_root_mean_squared_error: 2.4084 - val_loss: 7.8855 - val_y1_output_loss: 3.0378 - val_y2_output_loss: 4.5766 - val_y1_output_root_mean_squared_error: 1.7718 - val_y2_output_root_mean_squared_error: 2.1786
# Epoch 46/500
# 614/614 [==============================] - 0s 144us/sample - loss: 7.1635 - y1_output_loss: 2.1570 - y2_output_loss: 5.0677 - y1_output_root_mean_squared_error: 1.4661 - y2_output_root_mean_squared_error: 2.2392 - val_loss: 6.7063 - val_y1_output_loss: 2.2889 - val_y2_output_loss: 4.3192 - val_y1_output_root_mean_squared_error: 1.5213 - val_y2_output_root_mean_squared_error: 2.0957
# Epoch 47/500
# 614/614 [==============================] - 0s 151us/sample - loss: 7.2225 - y1_output_loss: 2.2125 - y2_output_loss: 4.9657 - y1_output_root_mean_squared_error: 1.4927 - y2_output_root_mean_squared_error: 2.2348 - val_loss: 10.3459 - val_y1_output_loss: 4.1133 - val_y2_output_loss: 6.1012 - val_y1_output_root_mean_squared_error: 2.0307 - val_y2_output_root_mean_squared_error: 2.4945
# Epoch 48/500
# 614/614 [==============================] - 0s 143us/sample - loss: 7.4841 - y1_output_loss: 2.3266 - y2_output_loss: 5.0923 - y1_output_root_mean_squared_error: 1.5321 - y2_output_root_mean_squared_error: 2.2664 - val_loss: 9.2647 - val_y1_output_loss: 3.5975 - val_y2_output_loss: 5.3980 - val_y1_output_root_mean_squared_error: 1.9207 - val_y2_output_root_mean_squared_error: 2.3612
# Epoch 49/500
# 614/614 [==============================] - 0s 148us/sample - loss: 6.8529 - y1_output_loss: 2.0670 - y2_output_loss: 4.7282 - y1_output_root_mean_squared_error: 1.4426 - y2_output_root_mean_squared_error: 2.1844 - val_loss: 6.8949 - val_y1_output_loss: 2.8894 - val_y2_output_loss: 3.7879 - val_y1_output_root_mean_squared_error: 1.7259 - val_y2_output_root_mean_squared_error: 1.9790
# Epoch 50/500
# 614/614 [==============================] - 0s 142us/sample - loss: 12.2255 - y1_output_loss: 3.9905 - y2_output_loss: 8.1600 - y1_output_root_mean_squared_error: 2.0062 - y2_output_root_mean_squared_error: 2.8637 - val_loss: 8.1487 - val_y1_output_loss: 2.3891 - val_y2_output_loss: 5.6363 - val_y1_output_root_mean_squared_error: 1.5529 - val_y2_output_root_mean_squared_error: 2.3953
# Epoch 51/500
# 614/614 [==============================] - 0s 145us/sample - loss: 6.1824 - y1_output_loss: 1.8059 - y2_output_loss: 4.3375 - y1_output_root_mean_squared_error: 1.3452 - y2_output_root_mean_squared_error: 2.0912 - val_loss: 7.0152 - val_y1_output_loss: 2.2774 - val_y2_output_loss: 4.5456 - val_y1_output_root_mean_squared_error: 1.5350 - val_y2_output_root_mean_squared_error: 2.1584
# Epoch 52/500
# 614/614 [==============================] - 0s 148us/sample - loss: 13.1416 - y1_output_loss: 3.7839 - y2_output_loss: 9.2739 - y1_output_root_mean_squared_error: 1.9532 - y2_output_root_mean_squared_error: 3.0539 - val_loss: 6.7865 - val_y1_output_loss: 2.9592 - val_y2_output_loss: 3.6250 - val_y1_output_root_mean_squared_error: 1.7398 - val_y2_output_root_mean_squared_error: 1.9390
# Epoch 53/500
# 614/614 [==============================] - 0s 156us/sample - loss: 8.0770 - y1_output_loss: 2.4026 - y2_output_loss: 5.6271 - y1_output_root_mean_squared_error: 1.5508 - y2_output_root_mean_squared_error: 2.3816 - val_loss: 5.7670 - val_y1_output_loss: 2.4478 - val_y2_output_loss: 3.1608 - val_y1_output_root_mean_squared_error: 1.5898 - val_y2_output_root_mean_squared_error: 1.7998
# Epoch 54/500
# 614/614 [==============================] - 0s 146us/sample - loss: 6.8114 - y1_output_loss: 2.1204 - y2_output_loss: 4.6754 - y1_output_root_mean_squared_error: 1.4601 - y2_output_root_mean_squared_error: 2.1632 - val_loss: 5.8435 - val_y1_output_loss: 2.2818 - val_y2_output_loss: 3.3809 - val_y1_output_root_mean_squared_error: 1.5325 - val_y2_output_root_mean_squared_error: 1.8695
# Epoch 55/500
# 614/614 [==============================] - 0s 141us/sample - loss: 7.1469 - y1_output_loss: 2.0512 - y2_output_loss: 5.1010 - y1_output_root_mean_squared_error: 1.4199 - y2_output_root_mean_squared_error: 2.2651 - val_loss: 10.8809 - val_y1_output_loss: 4.6664 - val_y2_output_loss: 5.9728 - val_y1_output_root_mean_squared_error: 2.1781 - val_y2_output_root_mean_squared_error: 2.4773
# Epoch 56/500
# 614/614 [==============================] - 0s 139us/sample - loss: 5.7209 - y1_output_loss: 1.8207 - y2_output_loss: 3.9691 - y1_output_root_mean_squared_error: 1.3357 - y2_output_root_mean_squared_error: 1.9841 - val_loss: 4.9844 - val_y1_output_loss: 2.0398 - val_y2_output_loss: 2.7684 - val_y1_output_root_mean_squared_error: 1.4531 - val_y2_output_root_mean_squared_error: 1.6949
# Epoch 57/500
# 614/614 [==============================] - 0s 136us/sample - loss: 5.1253 - y1_output_loss: 1.4822 - y2_output_loss: 3.6855 - y1_output_root_mean_squared_error: 1.2083 - y2_output_root_mean_squared_error: 1.9145 - val_loss: 15.5141 - val_y1_output_loss: 5.5496 - val_y2_output_loss: 9.4905 - val_y1_output_root_mean_squared_error: 2.3990 - val_y2_output_root_mean_squared_error: 3.1239
# Epoch 58/500
# 614/614 [==============================] - 0s 147us/sample - loss: 5.6738 - y1_output_loss: 1.6251 - y2_output_loss: 4.0002 - y1_output_root_mean_squared_error: 1.2787 - y2_output_root_mean_squared_error: 2.0097 - val_loss: 4.9646 - val_y1_output_loss: 1.8697 - val_y2_output_loss: 2.9711 - val_y1_output_root_mean_squared_error: 1.3820 - val_y2_output_root_mean_squared_error: 1.7477
# Epoch 59/500
# 614/614 [==============================] - 0s 156us/sample - loss: 5.5653 - y1_output_loss: 1.5316 - y2_output_loss: 4.0038 - y1_output_root_mean_squared_error: 1.2412 - y2_output_root_mean_squared_error: 2.0062 - val_loss: 4.4389 - val_y1_output_loss: 1.6255 - val_y2_output_loss: 2.6665 - val_y1_output_root_mean_squared_error: 1.2967 - val_y2_output_root_mean_squared_error: 1.6606
# Epoch 60/500
# 614/614 [==============================] - 0s 152us/sample - loss: 5.8618 - y1_output_loss: 1.6984 - y2_output_loss: 4.1181 - y1_output_root_mean_squared_error: 1.3056 - y2_output_root_mean_squared_error: 2.0389 - val_loss: 6.0125 - val_y1_output_loss: 1.7453 - val_y2_output_loss: 4.0762 - val_y1_output_root_mean_squared_error: 1.3444 - val_y2_output_root_mean_squared_error: 2.0507
# Epoch 61/500
# 614/614 [==============================] - 0s 142us/sample - loss: 5.7264 - y1_output_loss: 1.6035 - y2_output_loss: 4.0769 - y1_output_root_mean_squared_error: 1.2713 - y2_output_root_mean_squared_error: 2.0273 - val_loss: 6.4398 - val_y1_output_loss: 2.4537 - val_y2_output_loss: 3.7644 - val_y1_output_root_mean_squared_error: 1.5954 - val_y2_output_root_mean_squared_error: 1.9735
# Epoch 62/500
# 614/614 [==============================] - 0s 143us/sample - loss: 5.9741 - y1_output_loss: 1.5739 - y2_output_loss: 4.3456 - y1_output_root_mean_squared_error: 1.2599 - y2_output_root_mean_squared_error: 2.0944 - val_loss: 4.6541 - val_y1_output_loss: 1.6451 - val_y2_output_loss: 2.8816 - val_y1_output_root_mean_squared_error: 1.2969 - val_y2_output_root_mean_squared_error: 1.7240
# Epoch 63/500
# 614/614 [==============================] - 0s 136us/sample - loss: 5.0825 - y1_output_loss: 1.4227 - y2_output_loss: 3.6432 - y1_output_root_mean_squared_error: 1.1932 - y2_output_root_mean_squared_error: 1.9128 - val_loss: 5.9528 - val_y1_output_loss: 1.9905 - val_y2_output_loss: 3.7643 - val_y1_output_root_mean_squared_error: 1.4321 - val_y2_output_root_mean_squared_error: 1.9753
# Epoch 64/500
# 614/614 [==============================] - 0s 142us/sample - loss: 5.4440 - y1_output_loss: 1.4838 - y2_output_loss: 3.9246 - y1_output_root_mean_squared_error: 1.2222 - y2_output_root_mean_squared_error: 1.9875 - val_loss: 4.5752 - val_y1_output_loss: 1.7661 - val_y2_output_loss: 2.7008 - val_y1_output_root_mean_squared_error: 1.3484 - val_y2_output_root_mean_squared_error: 1.6604
# Epoch 65/500
# 614/614 [==============================] - 0s 159us/sample - loss: 6.4630 - y1_output_loss: 1.7920 - y2_output_loss: 4.6907 - y1_output_root_mean_squared_error: 1.3339 - y2_output_root_mean_squared_error: 2.1642 - val_loss: 12.5186 - val_y1_output_loss: 1.6743 - val_y2_output_loss: 10.5651 - val_y1_output_root_mean_squared_error: 1.3137 - val_y2_output_root_mean_squared_error: 3.2852
# Epoch 66/500
# 614/614 [==============================] - 0s 153us/sample - loss: 4.2884 - y1_output_loss: 1.2006 - y2_output_loss: 3.0875 - y1_output_root_mean_squared_error: 1.0949 - y2_output_root_mean_squared_error: 1.7577 - val_loss: 4.1299 - val_y1_output_loss: 1.6418 - val_y2_output_loss: 2.3710 - val_y1_output_root_mean_squared_error: 1.2996 - val_y2_output_root_mean_squared_error: 1.5623
# Epoch 67/500
# 614/614 [==============================] - 0s 140us/sample - loss: 5.7286 - y1_output_loss: 1.4880 - y2_output_loss: 4.3095 - y1_output_root_mean_squared_error: 1.2250 - y2_output_root_mean_squared_error: 2.0562 - val_loss: 11.2518 - val_y1_output_loss: 1.7748 - val_y2_output_loss: 9.2862 - val_y1_output_root_mean_squared_error: 1.3534 - val_y2_output_root_mean_squared_error: 3.0692
# Epoch 68/500
# 614/614 [==============================] - 0s 136us/sample - loss: 6.5284 - y1_output_loss: 1.8241 - y2_output_loss: 4.6684 - y1_output_root_mean_squared_error: 1.3547 - y2_output_root_mean_squared_error: 2.1664 - val_loss: 3.4584 - val_y1_output_loss: 1.2680 - val_y2_output_loss: 2.0825 - val_y1_output_root_mean_squared_error: 1.1403 - val_y2_output_root_mean_squared_error: 1.4691
# Epoch 69/500
# 614/614 [==============================] - 0s 143us/sample - loss: 5.0973 - y1_output_loss: 1.2386 - y2_output_loss: 3.8209 - y1_output_root_mean_squared_error: 1.1174 - y2_output_root_mean_squared_error: 1.9618 - val_loss: 5.4183 - val_y1_output_loss: 1.8790 - val_y2_output_loss: 3.4894 - val_y1_output_root_mean_squared_error: 1.3752 - val_y2_output_root_mean_squared_error: 1.8781
# Epoch 70/500
# 614/614 [==============================] - 0s 151us/sample - loss: 3.9763 - y1_output_loss: 1.0832 - y2_output_loss: 2.9149 - y1_output_root_mean_squared_error: 1.0434 - y2_output_root_mean_squared_error: 1.6993 - val_loss: 4.6796 - val_y1_output_loss: 1.2929 - val_y2_output_loss: 3.3002 - val_y1_output_root_mean_squared_error: 1.1473 - val_y2_output_root_mean_squared_error: 1.8340
# Epoch 71/500
# 614/614 [==============================] - 0s 151us/sample - loss: 4.1639 - y1_output_loss: 1.1542 - y2_output_loss: 3.0030 - y1_output_root_mean_squared_error: 1.0738 - y2_output_root_mean_squared_error: 1.7352 - val_loss: 3.8880 - val_y1_output_loss: 1.5234 - val_y2_output_loss: 2.2674 - val_y1_output_root_mean_squared_error: 1.2517 - val_y2_output_root_mean_squared_error: 1.5236
# Epoch 72/500
# 614/614 [==============================] - 0s 157us/sample - loss: 3.8819 - y1_output_loss: 1.0563 - y2_output_loss: 2.8515 - y1_output_root_mean_squared_error: 1.0305 - y2_output_root_mean_squared_error: 1.6793 - val_loss: 5.0444 - val_y1_output_loss: 1.2906 - val_y2_output_loss: 3.5853 - val_y1_output_root_mean_squared_error: 1.1558 - val_y2_output_root_mean_squared_error: 1.9258
# Epoch 73/500
# 614/614 [==============================] - 0s 144us/sample - loss: 4.5496 - y1_output_loss: 1.3079 - y2_output_loss: 3.2624 - y1_output_root_mean_squared_error: 1.1421 - y2_output_root_mean_squared_error: 1.8014 - val_loss: 5.3222 - val_y1_output_loss: 2.0411 - val_y2_output_loss: 3.1012 - val_y1_output_root_mean_squared_error: 1.4527 - val_y2_output_root_mean_squared_error: 1.7922
# Epoch 74/500
# 614/614 [==============================] - 0s 146us/sample - loss: 7.6132 - y1_output_loss: 2.1381 - y2_output_loss: 5.4328 - y1_output_root_mean_squared_error: 1.4658 - y2_output_root_mean_squared_error: 2.3376 - val_loss: 4.4405 - val_y1_output_loss: 1.2599 - val_y2_output_loss: 3.0985 - val_y1_output_root_mean_squared_error: 1.1416 - val_y2_output_root_mean_squared_error: 1.7712
# Epoch 75/500
# 614/614 [==============================] - 0s 140us/sample - loss: 4.8732 - y1_output_loss: 1.2789 - y2_output_loss: 3.5532 - y1_output_root_mean_squared_error: 1.1354 - y2_output_root_mean_squared_error: 1.8932 - val_loss: 2.8445 - val_y1_output_loss: 0.9304 - val_y2_output_loss: 1.8209 - val_y1_output_root_mean_squared_error: 0.9812 - val_y2_output_root_mean_squared_error: 1.3718
# Epoch 76/500
# 614/614 [==============================] - 0s 144us/sample - loss: 3.8890 - y1_output_loss: 1.0680 - y2_output_loss: 2.8171 - y1_output_root_mean_squared_error: 1.0341 - y2_output_root_mean_squared_error: 1.6792 - val_loss: 4.2511 - val_y1_output_loss: 0.9869 - val_y2_output_loss: 3.1389 - val_y1_output_root_mean_squared_error: 1.0100 - val_y2_output_root_mean_squared_error: 1.7975
# Epoch 77/500
# 614/614 [==============================] - 0s 154us/sample - loss: 3.3270 - y1_output_loss: 0.8636 - y2_output_loss: 2.4784 - y1_output_root_mean_squared_error: 0.9329 - y2_output_root_mean_squared_error: 1.5674 - val_loss: 5.5787 - val_y1_output_loss: 1.3364 - val_y2_output_loss: 4.1339 - val_y1_output_root_mean_squared_error: 1.1752 - val_y2_output_root_mean_squared_error: 2.0488
# Epoch 78/500
# 614/614 [==============================] - 0s 146us/sample - loss: 5.0114 - y1_output_loss: 1.5127 - y2_output_loss: 3.4551 - y1_output_root_mean_squared_error: 1.2347 - y2_output_root_mean_squared_error: 1.8673 - val_loss: 2.5732 - val_y1_output_loss: 0.8691 - val_y2_output_loss: 1.6330 - val_y1_output_root_mean_squared_error: 0.9481 - val_y2_output_root_mean_squared_error: 1.2939
# Epoch 79/500
# 614/614 [==============================] - 0s 143us/sample - loss: 3.7252 - y1_output_loss: 0.8171 - y2_output_loss: 2.9076 - y1_output_root_mean_squared_error: 0.8944 - y2_output_root_mean_squared_error: 1.7103 - val_loss: 5.3131 - val_y1_output_loss: 1.8887 - val_y2_output_loss: 3.2458 - val_y1_output_root_mean_squared_error: 1.3989 - val_y2_output_root_mean_squared_error: 1.8320
# Epoch 80/500
# 614/614 [==============================] - 0s 143us/sample - loss: 3.4786 - y1_output_loss: 0.8101 - y2_output_loss: 2.6922 - y1_output_root_mean_squared_error: 0.9011 - y2_output_root_mean_squared_error: 1.6330 - val_loss: 7.9805 - val_y1_output_loss: 1.8756 - val_y2_output_loss: 5.9584 - val_y1_output_root_mean_squared_error: 1.3862 - val_y2_output_root_mean_squared_error: 2.4615
# Epoch 81/500
# 614/614 [==============================] - 0s 144us/sample - loss: 3.1826 - y1_output_loss: 0.7326 - y2_output_loss: 2.4253 - y1_output_root_mean_squared_error: 0.8593 - y2_output_root_mean_squared_error: 1.5634 - val_loss: 2.6253 - val_y1_output_loss: 0.8717 - val_y2_output_loss: 1.6915 - val_y1_output_root_mean_squared_error: 0.9469 - val_y2_output_root_mean_squared_error: 1.3148
# Epoch 82/500
# 614/614 [==============================] - 0s 145us/sample - loss: 3.1033 - y1_output_loss: 0.7496 - y2_output_loss: 2.3595 - y1_output_root_mean_squared_error: 0.8668 - y2_output_root_mean_squared_error: 1.5336 - val_loss: 3.5614 - val_y1_output_loss: 1.4131 - val_y2_output_loss: 2.0665 - val_y1_output_root_mean_squared_error: 1.1986 - val_y2_output_root_mean_squared_error: 1.4576
# Epoch 83/500
# 614/614 [==============================] - 0s 157us/sample - loss: 3.0692 - y1_output_loss: 0.8168 - y2_output_loss: 2.2480 - y1_output_root_mean_squared_error: 0.8962 - y2_output_root_mean_squared_error: 1.5053 - val_loss: 6.4382 - val_y1_output_loss: 2.3063 - val_y2_output_loss: 3.9112 - val_y1_output_root_mean_squared_error: 1.5450 - val_y2_output_root_mean_squared_error: 2.0128
# Epoch 84/500
# 614/614 [==============================] - 0s 156us/sample - loss: 2.8565 - y1_output_loss: 0.6956 - y2_output_loss: 2.1440 - y1_output_root_mean_squared_error: 0.8352 - y2_output_root_mean_squared_error: 1.4693 - val_loss: 3.6150 - val_y1_output_loss: 1.0161 - val_y2_output_loss: 2.5786 - val_y1_output_root_mean_squared_error: 1.0148 - val_y2_output_root_mean_squared_error: 1.6078
# Epoch 85/500
# 614/614 [==============================] - 0s 153us/sample - loss: 3.2211 - y1_output_loss: 0.7993 - y2_output_loss: 2.4098 - y1_output_root_mean_squared_error: 0.8961 - y2_output_root_mean_squared_error: 1.5550 - val_loss: 2.3035 - val_y1_output_loss: 0.7534 - val_y2_output_loss: 1.5273 - val_y1_output_root_mean_squared_error: 0.8795 - val_y2_output_root_mean_squared_error: 1.2369
# Epoch 86/500
# 614/614 [==============================] - 0s 149us/sample - loss: 3.0164 - y1_output_loss: 0.8054 - y2_output_loss: 2.3636 - y1_output_root_mean_squared_error: 0.8810 - y2_output_root_mean_squared_error: 1.4967 - val_loss: 7.2717 - val_y1_output_loss: 2.2801 - val_y2_output_loss: 4.7634 - val_y1_output_root_mean_squared_error: 1.5385 - val_y2_output_root_mean_squared_error: 2.2146
# Epoch 87/500
# 614/614 [==============================] - 0s 145us/sample - loss: 2.9008 - y1_output_loss: 0.7152 - y2_output_loss: 2.1828 - y1_output_root_mean_squared_error: 0.8455 - y2_output_root_mean_squared_error: 1.4785 - val_loss: 3.3293 - val_y1_output_loss: 0.9287 - val_y2_output_loss: 2.3043 - val_y1_output_root_mean_squared_error: 0.9741 - val_y2_output_root_mean_squared_error: 1.5429
# Epoch 88/500
# 614/614 [==============================] - 0s 145us/sample - loss: 3.9769 - y1_output_loss: 0.8892 - y2_output_loss: 3.1055 - y1_output_root_mean_squared_error: 0.9468 - y2_output_root_mean_squared_error: 1.7551 - val_loss: 11.7546 - val_y1_output_loss: 1.3959 - val_y2_output_loss: 10.1547 - val_y1_output_root_mean_squared_error: 1.1946 - val_y2_output_root_mean_squared_error: 3.2137
# Epoch 89/500
# 614/614 [==============================] - 0s 157us/sample - loss: 3.7684 - y1_output_loss: 0.8482 - y2_output_loss: 2.8950 - y1_output_root_mean_squared_error: 0.9246 - y2_output_root_mean_squared_error: 1.7069 - val_loss: 2.8544 - val_y1_output_loss: 1.0141 - val_y2_output_loss: 1.7465 - val_y1_output_root_mean_squared_error: 1.0232 - val_y2_output_root_mean_squared_error: 1.3444
# Epoch 90/500
# 614/614 [==============================] - 0s 150us/sample - loss: 2.7029 - y1_output_loss: 0.7103 - y2_output_loss: 1.9844 - y1_output_root_mean_squared_error: 0.8425 - y2_output_root_mean_squared_error: 1.4118 - val_loss: 4.0369 - val_y1_output_loss: 1.4498 - val_y2_output_loss: 2.5381 - val_y1_output_root_mean_squared_error: 1.2135 - val_y2_output_root_mean_squared_error: 1.6013
# Epoch 91/500
# 614/614 [==============================] - 0s 142us/sample - loss: 4.6386 - y1_output_loss: 1.4041 - y2_output_loss: 3.2126 - y1_output_root_mean_squared_error: 1.1898 - y2_output_root_mean_squared_error: 1.7953 - val_loss: 7.5010 - val_y1_output_loss: 1.8462 - val_y2_output_loss: 5.4349 - val_y1_output_root_mean_squared_error: 1.3797 - val_y2_output_root_mean_squared_error: 2.3659
# Epoch 92/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.2375 - y1_output_loss: 0.8490 - y2_output_loss: 2.3582 - y1_output_root_mean_squared_error: 0.9259 - y2_output_root_mean_squared_error: 1.5428 - val_loss: 2.4265 - val_y1_output_loss: 0.6015 - val_y2_output_loss: 1.7371 - val_y1_output_root_mean_squared_error: 0.7887 - val_y2_output_root_mean_squared_error: 1.3433
# Epoch 93/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.9520 - y1_output_loss: 0.7203 - y2_output_loss: 2.2498 - y1_output_root_mean_squared_error: 0.8505 - y2_output_root_mean_squared_error: 1.4929 - val_loss: 2.4738 - val_y1_output_loss: 0.8902 - val_y2_output_loss: 1.5272 - val_y1_output_root_mean_squared_error: 0.9540 - val_y2_output_root_mean_squared_error: 1.2505
# Epoch 94/500
# 614/614 [==============================] - 0s 148us/sample - loss: 3.0356 - y1_output_loss: 0.7090 - y2_output_loss: 2.3153 - y1_output_root_mean_squared_error: 0.8457 - y2_output_root_mean_squared_error: 1.5233 - val_loss: 3.1523 - val_y1_output_loss: 0.9540 - val_y2_output_loss: 2.1414 - val_y1_output_root_mean_squared_error: 0.9872 - val_y2_output_root_mean_squared_error: 1.4757
# Epoch 95/500
# 614/614 [==============================] - 0s 150us/sample - loss: 2.3868 - y1_output_loss: 0.5811 - y2_output_loss: 1.7870 - y1_output_root_mean_squared_error: 0.7635 - y2_output_root_mean_squared_error: 1.3431 - val_loss: 2.0688 - val_y1_output_loss: 0.6815 - val_y2_output_loss: 1.3254 - val_y1_output_root_mean_squared_error: 0.8387 - val_y2_output_root_mean_squared_error: 1.1685
# Epoch 96/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.6222 - y1_output_loss: 0.5410 - y2_output_loss: 2.0613 - y1_output_root_mean_squared_error: 0.7371 - y2_output_root_mean_squared_error: 1.4419 - val_loss: 3.2967 - val_y1_output_loss: 1.2771 - val_y2_output_loss: 1.9224 - val_y1_output_root_mean_squared_error: 1.1502 - val_y2_output_root_mean_squared_error: 1.4049
# Epoch 97/500
# 614/614 [==============================] - 0s 147us/sample - loss: 2.7264 - y1_output_loss: 0.6748 - y2_output_loss: 2.0559 - y1_output_root_mean_squared_error: 0.8222 - y2_output_root_mean_squared_error: 1.4319 - val_loss: 2.5873 - val_y1_output_loss: 0.7473 - val_y2_output_loss: 1.7635 - val_y1_output_root_mean_squared_error: 0.8766 - val_y2_output_root_mean_squared_error: 1.3486
# Epoch 98/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.7219 - y1_output_loss: 0.5424 - y2_output_loss: 2.1705 - y1_output_root_mean_squared_error: 0.7390 - y2_output_root_mean_squared_error: 1.4750 - val_loss: 2.9282 - val_y1_output_loss: 0.7396 - val_y2_output_loss: 2.1537 - val_y1_output_root_mean_squared_error: 0.8673 - val_y2_output_root_mean_squared_error: 1.4751
# Epoch 99/500
# 614/614 [==============================] - 0s 139us/sample - loss: 4.2412 - y1_output_loss: 1.0382 - y2_output_loss: 3.1678 - y1_output_root_mean_squared_error: 1.0225 - y2_output_root_mean_squared_error: 1.7877 - val_loss: 2.2613 - val_y1_output_loss: 0.6357 - val_y2_output_loss: 1.5472 - val_y1_output_root_mean_squared_error: 0.8103 - val_y2_output_root_mean_squared_error: 1.2668
# Epoch 100/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.5646 - y1_output_loss: 0.6607 - y2_output_loss: 1.9044 - y1_output_root_mean_squared_error: 0.8085 - y2_output_root_mean_squared_error: 1.3823 - val_loss: 4.6716 - val_y1_output_loss: 1.1990 - val_y2_output_loss: 3.3209 - val_y1_output_root_mean_squared_error: 1.1091 - val_y2_output_root_mean_squared_error: 1.8551
# Epoch 101/500
# 614/614 [==============================] - 0s 146us/sample - loss: 2.5380 - y1_output_loss: 0.6533 - y2_output_loss: 1.8829 - y1_output_root_mean_squared_error: 0.8070 - y2_output_root_mean_squared_error: 1.3736 - val_loss: 6.7892 - val_y1_output_loss: 2.7268 - val_y2_output_loss: 3.9222 - val_y1_output_root_mean_squared_error: 1.6726 - val_y2_output_root_mean_squared_error: 1.9979
# Epoch 102/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.3037 - y1_output_loss: 0.5991 - y2_output_loss: 1.6838 - y1_output_root_mean_squared_error: 0.7774 - y2_output_root_mean_squared_error: 1.3036 - val_loss: 2.3566 - val_y1_output_loss: 0.7082 - val_y2_output_loss: 1.5748 - val_y1_output_root_mean_squared_error: 0.8531 - val_y2_output_root_mean_squared_error: 1.2762
# Epoch 103/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.6890 - y1_output_loss: 0.6077 - y2_output_loss: 2.0850 - y1_output_root_mean_squared_error: 0.7799 - y2_output_root_mean_squared_error: 1.4425 - val_loss: 2.6215 - val_y1_output_loss: 0.6947 - val_y2_output_loss: 1.8371 - val_y1_output_root_mean_squared_error: 0.8469 - val_y2_output_root_mean_squared_error: 1.3800
# Epoch 104/500
# 614/614 [==============================] - 0s 156us/sample - loss: 2.2991 - y1_output_loss: 0.5073 - y2_output_loss: 1.8117 - y1_output_root_mean_squared_error: 0.7101 - y2_output_root_mean_squared_error: 1.3397 - val_loss: 1.7420 - val_y1_output_loss: 0.5363 - val_y2_output_loss: 1.2138 - val_y1_output_root_mean_squared_error: 0.7366 - val_y2_output_root_mean_squared_error: 1.0952
# Epoch 105/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.6195 - y1_output_loss: 0.7214 - y2_output_loss: 1.8853 - y1_output_root_mean_squared_error: 0.8482 - y2_output_root_mean_squared_error: 1.3784 - val_loss: 1.9701 - val_y1_output_loss: 0.6407 - val_y2_output_loss: 1.2800 - val_y1_output_root_mean_squared_error: 0.8092 - val_y2_output_root_mean_squared_error: 1.1469
# Epoch 106/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.4590 - y1_output_loss: 0.5251 - y2_output_loss: 1.9470 - y1_output_root_mean_squared_error: 0.7266 - y2_output_root_mean_squared_error: 1.3896 - val_loss: 2.3149 - val_y1_output_loss: 0.5653 - val_y2_output_loss: 1.6740 - val_y1_output_root_mean_squared_error: 0.7616 - val_y2_output_root_mean_squared_error: 1.3171
# Epoch 107/500
# 614/614 [==============================] - 0s 145us/sample - loss: 2.6339 - y1_output_loss: 0.6813 - y2_output_loss: 1.9439 - y1_output_root_mean_squared_error: 0.8273 - y2_output_root_mean_squared_error: 1.3962 - val_loss: 1.9585 - val_y1_output_loss: 0.5404 - val_y2_output_loss: 1.3835 - val_y1_output_root_mean_squared_error: 0.7462 - val_y2_output_root_mean_squared_error: 1.1839
# Epoch 108/500
# 614/614 [==============================] - 0s 144us/sample - loss: 2.1817 - y1_output_loss: 0.5064 - y2_output_loss: 1.6855 - y1_output_root_mean_squared_error: 0.7117 - y2_output_root_mean_squared_error: 1.2943 - val_loss: 5.1662 - val_y1_output_loss: 1.7397 - val_y2_output_loss: 3.3278 - val_y1_output_root_mean_squared_error: 1.3389 - val_y2_output_root_mean_squared_error: 1.8367
# Epoch 109/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.6122 - y1_output_loss: 0.6981 - y2_output_loss: 1.9324 - y1_output_root_mean_squared_error: 0.8181 - y2_output_root_mean_squared_error: 1.3939 - val_loss: 6.7034 - val_y1_output_loss: 2.4636 - val_y2_output_loss: 4.0448 - val_y1_output_root_mean_squared_error: 1.5898 - val_y2_output_root_mean_squared_error: 2.0435
# Epoch 110/500
# 614/614 [==============================] - 0s 139us/sample - loss: 3.9213 - y1_output_loss: 1.0251 - y2_output_loss: 2.8740 - y1_output_root_mean_squared_error: 1.0124 - y2_output_root_mean_squared_error: 1.7018 - val_loss: 1.9321 - val_y1_output_loss: 0.5359 - val_y2_output_loss: 1.3782 - val_y1_output_root_mean_squared_error: 0.7343 - val_y2_output_root_mean_squared_error: 1.1802
# Epoch 111/500
# 614/614 [==============================] - 0s 138us/sample - loss: 1.7908 - y1_output_loss: 0.4503 - y2_output_loss: 1.3698 - y1_output_root_mean_squared_error: 0.6526 - y2_output_root_mean_squared_error: 1.1683 - val_loss: 5.8267 - val_y1_output_loss: 2.5517 - val_y2_output_loss: 3.1971 - val_y1_output_root_mean_squared_error: 1.6100 - val_y2_output_root_mean_squared_error: 1.7985
# Epoch 112/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.2816 - y1_output_loss: 0.5304 - y2_output_loss: 1.7321 - y1_output_root_mean_squared_error: 0.7304 - y2_output_root_mean_squared_error: 1.3222 - val_loss: 1.6699 - val_y1_output_loss: 0.6032 - val_y2_output_loss: 1.0298 - val_y1_output_root_mean_squared_error: 0.7848 - val_y2_output_root_mean_squared_error: 1.0266
# Epoch 113/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.3429 - y1_output_loss: 0.9108 - y2_output_loss: 2.4052 - y1_output_root_mean_squared_error: 0.9571 - y2_output_root_mean_squared_error: 1.5579 - val_loss: 2.0681 - val_y1_output_loss: 0.7528 - val_y2_output_loss: 1.2716 - val_y1_output_root_mean_squared_error: 0.8765 - val_y2_output_root_mean_squared_error: 1.1401
# Epoch 114/500
# 614/614 [==============================] - 0s 146us/sample - loss: 2.0198 - y1_output_loss: 0.5052 - y2_output_loss: 1.5069 - y1_output_root_mean_squared_error: 0.7098 - y2_output_root_mean_squared_error: 1.2313 - val_loss: 1.9815 - val_y1_output_loss: 0.4838 - val_y2_output_loss: 1.4882 - val_y1_output_root_mean_squared_error: 0.7005 - val_y2_output_root_mean_squared_error: 1.2210
# Epoch 115/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.3537 - y1_output_loss: 0.5973 - y2_output_loss: 1.7814 - y1_output_root_mean_squared_error: 0.7674 - y2_output_root_mean_squared_error: 1.3285 - val_loss: 2.7109 - val_y1_output_loss: 1.0532 - val_y2_output_loss: 1.6341 - val_y1_output_root_mean_squared_error: 1.0296 - val_y2_output_root_mean_squared_error: 1.2848
# Epoch 116/500
# 614/614 [==============================] - 0s 135us/sample - loss: 1.8005 - y1_output_loss: 0.3943 - y2_output_loss: 1.4105 - y1_output_root_mean_squared_error: 0.6235 - y2_output_root_mean_squared_error: 1.1882 - val_loss: 2.0174 - val_y1_output_loss: 0.5890 - val_y2_output_loss: 1.4174 - val_y1_output_root_mean_squared_error: 0.7717 - val_y2_output_root_mean_squared_error: 1.1924
# Epoch 117/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.3431 - y1_output_loss: 0.4269 - y2_output_loss: 1.9421 - y1_output_root_mean_squared_error: 0.6539 - y2_output_root_mean_squared_error: 1.3840 - val_loss: 2.5750 - val_y1_output_loss: 0.6089 - val_y2_output_loss: 1.9870 - val_y1_output_root_mean_squared_error: 0.7853 - val_y2_output_root_mean_squared_error: 1.3994
# Epoch 118/500
# 614/614 [==============================] - 0s 132us/sample - loss: 1.8636 - y1_output_loss: 0.3940 - y2_output_loss: 1.4644 - y1_output_root_mean_squared_error: 0.6265 - y2_output_root_mean_squared_error: 1.2129 - val_loss: 3.2415 - val_y1_output_loss: 0.5693 - val_y2_output_loss: 2.5947 - val_y1_output_root_mean_squared_error: 0.7587 - val_y2_output_root_mean_squared_error: 1.6327
# Epoch 119/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.0299 - y1_output_loss: 0.4656 - y2_output_loss: 1.5471 - y1_output_root_mean_squared_error: 0.6850 - y2_output_root_mean_squared_error: 1.2493 - val_loss: 1.5531 - val_y1_output_loss: 0.4827 - val_y2_output_loss: 1.0496 - val_y1_output_root_mean_squared_error: 0.7009 - val_y2_output_root_mean_squared_error: 1.0304
# Epoch 120/500
# 614/614 [==============================] - 0s 146us/sample - loss: 1.8119 - y1_output_loss: 0.4443 - y2_output_loss: 1.3612 - y1_output_root_mean_squared_error: 0.6658 - y2_output_root_mean_squared_error: 1.1698 - val_loss: 2.8276 - val_y1_output_loss: 0.8682 - val_y2_output_loss: 1.8679 - val_y1_output_root_mean_squared_error: 0.9476 - val_y2_output_root_mean_squared_error: 1.3891
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3976 - y1_output_loss: 0.1316 - y2_output_loss: 0.2679 - y1_output_root_mean_squared_error: 0.3619 - y2_output_root_mean_squared_error: 0.5164 - val_loss: 0.8276 - val_y1_output_loss: 0.2184 - val_y2_output_loss: 0.5963 - val_y1_output_root_mean_squared_error: 0.4655 - val_y2_output_root_mean_squared_error: 0.7816
# Epoch 462/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.6262 - y1_output_loss: 0.1720 - y2_output_loss: 0.4526 - y1_output_root_mean_squared_error: 0.4127 - y2_output_root_mean_squared_error: 0.6752 - val_loss: 0.6909 - val_y1_output_loss: 0.2290 - val_y2_output_loss: 0.4562 - val_y1_output_root_mean_squared_error: 0.4732 - val_y2_output_root_mean_squared_error: 0.6834
# Epoch 463/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.3522 - y1_output_loss: 0.1123 - y2_output_loss: 0.2387 - y1_output_root_mean_squared_error: 0.3362 - y2_output_root_mean_squared_error: 0.4890 - val_loss: 0.7457 - val_y1_output_loss: 0.1976 - val_y2_output_loss: 0.5375 - val_y1_output_root_mean_squared_error: 0.4434 - val_y2_output_root_mean_squared_error: 0.7410
# Epoch 464/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3430 - y1_output_loss: 0.1126 - y2_output_loss: 0.2290 - y1_output_root_mean_squared_error: 0.3372 - y2_output_root_mean_squared_error: 0.4789 - val_loss: 1.2308 - val_y1_output_loss: 0.2785 - val_y2_output_loss: 0.9217 - val_y1_output_root_mean_squared_error: 0.5306 - val_y2_output_root_mean_squared_error: 0.9743
# Epoch 465/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.4410 - y1_output_loss: 0.1388 - y2_output_loss: 0.2997 - y1_output_root_mean_squared_error: 0.3733 - y2_output_root_mean_squared_error: 0.5492 - val_loss: 0.7703 - val_y1_output_loss: 0.2400 - val_y2_output_loss: 0.5108 - val_y1_output_root_mean_squared_error: 0.4936 - val_y2_output_root_mean_squared_error: 0.7257
# Epoch 466/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3203 - y1_output_loss: 0.1097 - y2_output_loss: 0.2109 - y1_output_root_mean_squared_error: 0.3321 - y2_output_root_mean_squared_error: 0.4583 - val_loss: 1.0259 - val_y1_output_loss: 0.1935 - val_y2_output_loss: 0.8159 - val_y1_output_root_mean_squared_error: 0.4376 - val_y2_output_root_mean_squared_error: 0.9134
# Epoch 467/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3395 - y1_output_loss: 0.1111 - y2_output_loss: 0.2282 - y1_output_root_mean_squared_error: 0.3318 - y2_output_root_mean_squared_error: 0.4790 - val_loss: 1.1408 - val_y1_output_loss: 0.4448 - val_y2_output_loss: 0.6621 - val_y1_output_root_mean_squared_error: 0.6739 - val_y2_output_root_mean_squared_error: 0.8286
# Epoch 468/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.3435 - y1_output_loss: 0.1309 - y2_output_loss: 0.2227 - y1_output_root_mean_squared_error: 0.3608 - y2_output_root_mean_squared_error: 0.4618 - val_loss: 3.0230 - val_y1_output_loss: 0.5117 - val_y2_output_loss: 2.4980 - val_y1_output_root_mean_squared_error: 0.7065 - val_y2_output_root_mean_squared_error: 1.5887
# Epoch 469/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.5386 - y1_output_loss: 0.1445 - y2_output_loss: 0.3904 - y1_output_root_mean_squared_error: 0.3813 - y2_output_root_mean_squared_error: 0.6270 - val_loss: 0.5878 - val_y1_output_loss: 0.1948 - val_y2_output_loss: 0.3827 - val_y1_output_root_mean_squared_error: 0.4413 - val_y2_output_root_mean_squared_error: 0.6270
# Epoch 470/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3742 - y1_output_loss: 0.1352 - y2_output_loss: 0.2407 - y1_output_root_mean_squared_error: 0.3682 - y2_output_root_mean_squared_error: 0.4884 - val_loss: 0.6844 - val_y1_output_loss: 0.2517 - val_y2_output_loss: 0.4290 - val_y1_output_root_mean_squared_error: 0.4917 - val_y2_output_root_mean_squared_error: 0.6653
# Epoch 471/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3072 - y1_output_loss: 0.1225 - y2_output_loss: 0.1824 - y1_output_root_mean_squared_error: 0.3511 - y2_output_root_mean_squared_error: 0.4289 - val_loss: 0.5553 - val_y1_output_loss: 0.1945 - val_y2_output_loss: 0.3511 - val_y1_output_root_mean_squared_error: 0.4404 - val_y2_output_root_mean_squared_error: 0.6011
# Epoch 472/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3455 - y1_output_loss: 0.1206 - y2_output_loss: 0.2255 - y1_output_root_mean_squared_error: 0.3475 - y2_output_root_mean_squared_error: 0.4741 - val_loss: 0.8872 - val_y1_output_loss: 0.2579 - val_y2_output_loss: 0.6216 - val_y1_output_root_mean_squared_error: 0.5013 - val_y2_output_root_mean_squared_error: 0.7974
# Epoch 473/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.2979 - y1_output_loss: 0.1031 - y2_output_loss: 0.1971 - y1_output_root_mean_squared_error: 0.3223 - y2_output_root_mean_squared_error: 0.4405 - val_loss: 1.1492 - val_y1_output_loss: 0.2395 - val_y2_output_loss: 0.8852 - val_y1_output_root_mean_squared_error: 0.4930 - val_y2_output_root_mean_squared_error: 0.9519
# Epoch 474/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.3487 - y1_output_loss: 0.1190 - y2_output_loss: 0.2298 - y1_output_root_mean_squared_error: 0.3459 - y2_output_root_mean_squared_error: 0.4786 - val_loss: 0.5675 - val_y1_output_loss: 0.2027 - val_y2_output_loss: 0.3546 - val_y1_output_root_mean_squared_error: 0.4478 - val_y2_output_root_mean_squared_error: 0.6058
# Epoch 475/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.3938 - y1_output_loss: 0.1228 - y2_output_loss: 0.2703 - y1_output_root_mean_squared_error: 0.3478 - y2_output_root_mean_squared_error: 0.5223 - val_loss: 0.8309 - val_y1_output_loss: 0.3085 - val_y2_output_loss: 0.5041 - val_y1_output_root_mean_squared_error: 0.5596 - val_y2_output_root_mean_squared_error: 0.7195
# Epoch 476/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.3294 - y1_output_loss: 0.1152 - y2_output_loss: 0.2139 - y1_output_root_mean_squared_error: 0.3402 - y2_output_root_mean_squared_error: 0.4623 - val_loss: 0.6683 - val_y1_output_loss: 0.2825 - val_y2_output_loss: 0.3837 - val_y1_output_root_mean_squared_error: 0.5259 - val_y2_output_root_mean_squared_error: 0.6259
# Epoch 477/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4163 - y1_output_loss: 0.1382 - y2_output_loss: 0.2767 - y1_output_root_mean_squared_error: 0.3716 - y2_output_root_mean_squared_error: 0.5274 - val_loss: 0.7200 - val_y1_output_loss: 0.2505 - val_y2_output_loss: 0.4528 - val_y1_output_root_mean_squared_error: 0.5030 - val_y2_output_root_mean_squared_error: 0.6834
# Epoch 478/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4053 - y1_output_loss: 0.1385 - y2_output_loss: 0.2644 - y1_output_root_mean_squared_error: 0.3733 - y2_output_root_mean_squared_error: 0.5157 - val_loss: 0.7063 - val_y1_output_loss: 0.2339 - val_y2_output_loss: 0.4681 - val_y1_output_root_mean_squared_error: 0.4808 - val_y2_output_root_mean_squared_error: 0.6893
# Epoch 479/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3271 - y1_output_loss: 0.1184 - y2_output_loss: 0.2063 - y1_output_root_mean_squared_error: 0.3455 - y2_output_root_mean_squared_error: 0.4558 - val_loss: 0.8014 - val_y1_output_loss: 0.2273 - val_y2_output_loss: 0.5635 - val_y1_output_root_mean_squared_error: 0.4712 - val_y2_output_root_mean_squared_error: 0.7611
# Epoch 480/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3933 - y1_output_loss: 0.1278 - y2_output_loss: 0.2656 - y1_output_root_mean_squared_error: 0.3577 - y2_output_root_mean_squared_error: 0.5151 - val_loss: 0.5959 - val_y1_output_loss: 0.2017 - val_y2_output_loss: 0.3847 - val_y1_output_root_mean_squared_error: 0.4459 - val_y2_output_root_mean_squared_error: 0.6301
# Epoch 481/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3684 - y1_output_loss: 0.1251 - y2_output_loss: 0.2399 - y1_output_root_mean_squared_error: 0.3552 - y2_output_root_mean_squared_error: 0.4922 - val_loss: 0.5565 - val_y1_output_loss: 0.1833 - val_y2_output_loss: 0.3643 - val_y1_output_root_mean_squared_error: 0.4265 - val_y2_output_root_mean_squared_error: 0.6120
# Epoch 482/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.2785 - y1_output_loss: 0.1142 - y2_output_loss: 0.1644 - y1_output_root_mean_squared_error: 0.3375 - y2_output_root_mean_squared_error: 0.4056 - val_loss: 0.6765 - val_y1_output_loss: 0.2161 - val_y2_output_loss: 0.4477 - val_y1_output_root_mean_squared_error: 0.4662 - val_y2_output_root_mean_squared_error: 0.6776
# Epoch 483/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.2495 - y1_output_loss: 0.1033 - y2_output_loss: 0.1478 - y1_output_root_mean_squared_error: 0.3217 - y2_output_root_mean_squared_error: 0.3822 - val_loss: 0.6798 - val_y1_output_loss: 0.2098 - val_y2_output_loss: 0.4606 - val_y1_output_root_mean_squared_error: 0.4561 - val_y2_output_root_mean_squared_error: 0.6869
# Epoch 484/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3139 - y1_output_loss: 0.1141 - y2_output_loss: 0.1996 - y1_output_root_mean_squared_error: 0.3378 - y2_output_root_mean_squared_error: 0.4470 - val_loss: 0.7167 - val_y1_output_loss: 0.2009 - val_y2_output_loss: 0.5030 - val_y1_output_root_mean_squared_error: 0.4435 - val_y2_output_root_mean_squared_error: 0.7211
# Epoch 485/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.3385 - y1_output_loss: 0.1132 - y2_output_loss: 0.2244 - y1_output_root_mean_squared_error: 0.3378 - y2_output_root_mean_squared_error: 0.4737 - val_loss: 0.6541 - val_y1_output_loss: 0.2105 - val_y2_output_loss: 0.4365 - val_y1_output_root_mean_squared_error: 0.4545 - val_y2_output_root_mean_squared_error: 0.6690
# Epoch 486/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.2593 - y1_output_loss: 0.0993 - y2_output_loss: 0.1585 - y1_output_root_mean_squared_error: 0.3163 - y2_output_root_mean_squared_error: 0.3991 - val_loss: 0.6459 - val_y1_output_loss: 0.2007 - val_y2_output_loss: 0.4340 - val_y1_output_root_mean_squared_error: 0.4449 - val_y2_output_root_mean_squared_error: 0.6693
# Epoch 487/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.3505 - y1_output_loss: 0.1203 - y2_output_loss: 0.2277 - y1_output_root_mean_squared_error: 0.3474 - y2_output_root_mean_squared_error: 0.4794 - val_loss: 0.5871 - val_y1_output_loss: 0.2200 - val_y2_output_loss: 0.3561 - val_y1_output_root_mean_squared_error: 0.4670 - val_y2_output_root_mean_squared_error: 0.6075
# Epoch 488/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.3049 - y1_output_loss: 0.1025 - y2_output_loss: 0.2016 - y1_output_root_mean_squared_error: 0.3200 - y2_output_root_mean_squared_error: 0.4500 - val_loss: 0.6143 - val_y1_output_loss: 0.2082 - val_y2_output_loss: 0.3914 - val_y1_output_root_mean_squared_error: 0.4565 - val_y2_output_root_mean_squared_error: 0.6371
# Epoch 489/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3049 - y1_output_loss: 0.1173 - y2_output_loss: 0.1856 - y1_output_root_mean_squared_error: 0.3433 - y2_output_root_mean_squared_error: 0.4325 - val_loss: 0.5296 - val_y1_output_loss: 0.1991 - val_y2_output_loss: 0.3232 - val_y1_output_root_mean_squared_error: 0.4413 - val_y2_output_root_mean_squared_error: 0.5787
# Epoch 490/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3223 - y1_output_loss: 0.1220 - y2_output_loss: 0.1985 - y1_output_root_mean_squared_error: 0.3497 - y2_output_root_mean_squared_error: 0.4473 - val_loss: 0.5599 - val_y1_output_loss: 0.1944 - val_y2_output_loss: 0.3581 - val_y1_output_root_mean_squared_error: 0.4355 - val_y2_output_root_mean_squared_error: 0.6084
# Epoch 491/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3912 - y1_output_loss: 0.1186 - y2_output_loss: 0.2696 - y1_output_root_mean_squared_error: 0.3456 - y2_output_root_mean_squared_error: 0.5213 - val_loss: 0.6088 - val_y1_output_loss: 0.2223 - val_y2_output_loss: 0.3771 - val_y1_output_root_mean_squared_error: 0.4716 - val_y2_output_root_mean_squared_error: 0.6216
# Epoch 492/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4189 - y1_output_loss: 0.1354 - y2_output_loss: 0.2852 - y1_output_root_mean_squared_error: 0.3693 - y2_output_root_mean_squared_error: 0.5316 - val_loss: 0.5776 - val_y1_output_loss: 0.2134 - val_y2_output_loss: 0.3562 - val_y1_output_root_mean_squared_error: 0.4564 - val_y2_output_root_mean_squared_error: 0.6077
# Epoch 493/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3003 - y1_output_loss: 0.1127 - y2_output_loss: 0.1882 - y1_output_root_mean_squared_error: 0.3360 - y2_output_root_mean_squared_error: 0.4329 - val_loss: 0.6069 - val_y1_output_loss: 0.2357 - val_y2_output_loss: 0.3632 - val_y1_output_root_mean_squared_error: 0.4804 - val_y2_output_root_mean_squared_error: 0.6133
# Epoch 494/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.3554 - y1_output_loss: 0.1111 - y2_output_loss: 0.2416 - y1_output_root_mean_squared_error: 0.3345 - y2_output_root_mean_squared_error: 0.4935 - val_loss: 0.6131 - val_y1_output_loss: 0.2075 - val_y2_output_loss: 0.3949 - val_y1_output_root_mean_squared_error: 0.4546 - val_y2_output_root_mean_squared_error: 0.6375
# Epoch 495/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.2835 - y1_output_loss: 0.1096 - y2_output_loss: 0.1723 - y1_output_root_mean_squared_error: 0.3323 - y2_output_root_mean_squared_error: 0.4160 - val_loss: 0.5832 - val_y1_output_loss: 0.2109 - val_y2_output_loss: 0.3647 - val_y1_output_root_mean_squared_error: 0.4571 - val_y2_output_root_mean_squared_error: 0.6117
# Epoch 496/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.2654 - y1_output_loss: 0.1000 - y2_output_loss: 0.1649 - y1_output_root_mean_squared_error: 0.3165 - y2_output_root_mean_squared_error: 0.4064 - val_loss: 0.6662 - val_y1_output_loss: 0.2118 - val_y2_output_loss: 0.4424 - val_y1_output_root_mean_squared_error: 0.4585 - val_y2_output_root_mean_squared_error: 0.6753
# Epoch 497/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3017 - y1_output_loss: 0.1088 - y2_output_loss: 0.1920 - y1_output_root_mean_squared_error: 0.3310 - y2_output_root_mean_squared_error: 0.4384 - val_loss: 0.5505 - val_y1_output_loss: 0.1982 - val_y2_output_loss: 0.3436 - val_y1_output_root_mean_squared_error: 0.4418 - val_y2_output_root_mean_squared_error: 0.5960
# Epoch 498/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.2866 - y1_output_loss: 0.1165 - y2_output_loss: 0.1682 - y1_output_root_mean_squared_error: 0.3422 - y2_output_root_mean_squared_error: 0.4116 - val_loss: 0.5760 - val_y1_output_loss: 0.2085 - val_y2_output_loss: 0.3621 - val_y1_output_root_mean_squared_error: 0.4499 - val_y2_output_root_mean_squared_error: 0.6112
# Epoch 499/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3487 - y1_output_loss: 0.1179 - y2_output_loss: 0.2301 - y1_output_root_mean_squared_error: 0.3429 - y2_output_root_mean_squared_error: 0.4807 - val_loss: 0.6116 - val_y1_output_loss: 0.2112 - val_y2_output_loss: 0.3890 - val_y1_output_root_mean_squared_error: 0.4578 - val_y2_output_root_mean_squared_error: 0.6341
# Epoch 500/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3490 - y1_output_loss: 0.1217 - y2_output_loss: 0.2247 - y1_output_root_mean_squared_error: 0.3504 - y2_output_root_mean_squared_error: 0.4756 - val_loss: 0.6612 - val_y1_output_loss: 0.2759 - val_y2_output_loss: 0.3742 - val_y1_output_root_mean_squared_error: 0.5220 - val_y2_output_root_mean_squared_error: 0.6234

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 37us/sample - loss: 0.6612 - y1_output_loss: 0.2789 - y2_output_loss: 0.3812 - y1_output_root_mean_squared_error: 0.5220 - y2_output_root_mean_squared_error: 0.6234
# Loss = 0.6611963928519905, Y1_loss = 0.2789497971534729, Y1_mse = 0.5220445394515991, Y2_loss = 0.3811735510826111, Y2_mse = 0.6234306693077087

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
